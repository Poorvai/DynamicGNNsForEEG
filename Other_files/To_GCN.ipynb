# %%
import numpy as np
import torch
import torch.nn as nn
from sklearn.preprocessing import StandardScaler
from torch.utils.data import DataLoader, TensorDataset
import scipy.io as io
import os

# %%
device = torch.device('mps' if torch.backends.mps.is_available() else 'cpu')
print("Using device:", device)
# Out:
# Using device: mps

# %% [markdown]
# ### Obtaining data in time_steps

# %% [markdown]
# Steps:
# 1. Open n interictal matrices
# 2. from each matrix, divide into 1000 step time windows => No. of windows =
# 3. from Pre-trained RNN, obtain temporal embeddings for each channel in each time window, increase seq length to 100?
# 4. Save into a folder with labelled time_steps

# %% [markdown]
# Model
